# %%
filenames = [
    {'filename' : 'bookings'},
    {'filename' : 'airports'},
    {'filename' : 'flights'},
    {'filename' : 'passengers'} 
    ]

# %%
dbutils.jobs.taskValues.set('filenames', filenames)
